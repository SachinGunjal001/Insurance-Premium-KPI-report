# %%
import pandas as pd

# %%
df = pd.read_clipboard()
df.head()
# Out:
# Empty DataFrame
# Columns: [WinterComing$12]
# Index: []

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='insight.html')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 from ydata_profiling import ProfileReport
# ----> 2 prof = ProfileReport(df)
#       3 prof.to_file(output_file='insight.html')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ydata_profiling\profile_report.py:109, in ProfileReport.__init__(self, df, minimal, tsmode, sortby, sensitive, explorative, sample, config_file, lazy, typeset, summarizer, config, type_schema, **kwargs)
#      68 def __init__(
#      69     self,
#      70     df: Optional[Union[pd.DataFrame, sDataFrame]] = None,
#    (...)     83     **kwargs,
#      84 ):
#      85     """Generate a ProfileReport based on a pandas or spark.sql DataFrame
#      86
#      87     Config processing order (in case of duplicate entries, entries later in the order are retained):
# ...
