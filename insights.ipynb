# %%
import pandas as pd

# %%
df = pd.read_clipboard()
df.head()
# Out:
#     Policy Number        Start Date    Last Paid Date  Tenure (Years)  \
# 0  TRS-POL-892387     18 April 2022     18 April 2025              20
# 1  TRS-POL-603900     19 April 2019     19 April 2025              20
# 2  TRS-POL-336174    12 August 2019    12 August 2025              20
# 3  TRS-POL-745853  14 November 2016  14 November 2025              20
# 4  TRS-POL-799138      09 June 2017      09 June 2025              20
#
#    Date of Purchase  Customer ID  Sum Assured INR/Coverage Amount  \
# 0     18 April 2022  CUST-189349                        619301.17
# 1     19 April 2019  CUST-802812                       1330929.44
# 2    12 August 2019  CUST-541584                        714993.62
# 3  14 November 2016  CUST-192788                        270848.26
# 4      09 June 2017  CUST-221834                       1885143.74
#
#    Premium Amount Payment Frequency  Underwriting expenses  ...  \
# 0        42085.47         Quarterly                3335.88  ...
# 1        24594.09         Quarterly                7587.61  ...
# 2        76687.52         Quarterly                4288.23  ...
# 3        18826.75         Quarterly                6725.00  ...
# 4        93979.29         Quarterly                5369.76  ...
#
#   Premium Payment Duration Total Premium paid Total Premium Payable  \
# 0                        3          505025.64            2861811.96
# 1                        6          590258.16            1377269.04
# 2                        6         1840500.48            4294501.12
# 3                        9          677763.00             828377.00
# 4                        8         3007337.28            4511005.92
#
#    Maturity Amount Annualized ROI (%) profit/gain Tenure Date  \
# 0      3686687.172             10.45%  319849.572  18-04-2042
# 1      2154442.284              6.69%  186915.084  19-04-2039
# 2      6717826.752              6.69%  582825.152  12-08-2039
# 3      1619100.500              4.45%  112960.500  14-11-2036
# 4      8232585.804              5.16%  714242.604  09-06-2037
#
#   MaturedIn 5 years MaturedIn 10 years MaturedIn 15 years
# 0                 0                  0                  0
# 1                 0                  0                  1
# 2                 0                  0                  1
# 3                 0                  0                  1
# 4                 0                  0                  1
#
# [5 rows x 33 columns]

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='insights.html')
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 33/33 [00:21<00:00,  1.51it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from ydata-profiling import profileReport
prf = profileReport(df)
prof.to_file(output_file='output.html')
